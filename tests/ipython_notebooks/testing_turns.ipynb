# %%
# MOVE TO THE UTILS FOLDER TO GET RID OF IMPORT ERROR
import pandas as pd
import numpy as np
from preprocess import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/agshruti/Documents/tpm/team-process-map/feature_engine/testing/ipython_notebooks/testing_turns.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/Users/agshruti/Documents/tpm/team-process-map/feature_engine/testing/ipython_notebooks/testing_turns.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/agshruti/Documents/tpm/team-process-map/feature_engine/testing/ipython_notebooks/testing_turns.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/Users/agshruti/Documents/tpm/team-process-map/feature_engine/testing/ipython_notebooks/testing_turns.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from ...utils.preprocess import *
#
# ImportError: attempted relative import with no known parent package

# %%
df = pd.read_csv('../data/raw_data/jury_conversations_with_outcome_var.csv')
df
# Out:
#        batch_num  round_num          speaker_nickname
# 0              0          0  5e7e1e0031f4e454e196c30b  \
# 1              0          0  5e31d6e4e31c5304c46f1413
# 2              0          0  5e7e4f4c31f4e454e196c9c4
# 3              0          0  5d482ea421c9be351f762255
# 4              0          0  5e84cc3c50f6e364321d6265
# ...          ...        ...                       ...
# 14883        177          3  5f1f466846a7f03dda9b37c3
# 14884        177          3  5f1a214246a7f03dda9a6aad
# 14885        177          3  5f2096dab0aafc741f6865bb
# 14886        177          3  5f1f472646a7f03dda9b3895
# 14887        177          3  5f1f466846a7f03dda9b37c3
#
#                       timestamp
# 0      2020-04-20T18:27:20.125Z  \
# 1      2020-04-20T18:27:23.764Z
# 2      2020-04-20T18:27:27.724Z
# 3      2020-04-20T18:27:30.410Z
# 4      2020-04-20T18:27:35.506Z
# ...                         ...
# 14883  2020-07-28T22:36:22.226Z
# 14884  2020-07-28T22:36:46.155Z
# ...

# %%
conv = df.loc[((df['batch_num'] == 0 )& (df['round_num'] == 0))]
conv
# Out:
#     batch_num  round_num          speaker_nickname                 timestamp
# 0           0          0  5e7e1e0031f4e454e196c30b  2020-04-20T18:27:20.125Z  \
# 1           0          0  5e31d6e4e31c5304c46f1413  2020-04-20T18:27:23.764Z
# 2           0          0  5e7e4f4c31f4e454e196c9c4  2020-04-20T18:27:27.724Z
# 3           0          0  5d482ea421c9be351f762255  2020-04-20T18:27:30.410Z
# 4           0          0  5e84cc3c50f6e364321d6265  2020-04-20T18:27:35.506Z
# 5           0          0  5d482ea621c9be351f762ae5  2020-04-20T18:28:09.451Z
# 6           0          0  5e84cc3c50f6e364321d6265  2020-04-20T18:28:20.136Z
# 7           0          0  5e7e4f4c31f4e454e196c9c4  2020-04-20T18:28:28.501Z
# 8           0          0  5e7e1e0031f4e454e196c30b  2020-04-20T18:28:30.530Z
# 9           0          0  5d482ea421c9be351f762255  2020-04-20T18:28:30.637Z
# 10          0          0  5e7e1e0031f4e454e196c30b  2020-04-20T18:28:50.848Z
# ...

# %%
preprocess_conversation_columns(df)
df["message_lower_with_punc"] = df["message"].astype(str).apply(preprocess_text_lowercase_but_retain_punctuation)
df
# Out:
#        batch_num  round_num          speaker_nickname
# 0              0          0  5e7e1e0031f4e454e196c30b  \
# 1              0          0  5e31d6e4e31c5304c46f1413
# 2              0          0  5e7e4f4c31f4e454e196c9c4
# 3              0          0  5d482ea421c9be351f762255
# 4              0          0  5e84cc3c50f6e364321d6265
# ...          ...        ...                       ...
# 14883        177          3  5f1f466846a7f03dda9b37c3
# 14884        177          3  5f1a214246a7f03dda9a6aad
# 14885        177          3  5f2096dab0aafc741f6865bb
# 14886        177          3  5f1f472646a7f03dda9b3895
# 14887        177          3  5f1f466846a7f03dda9b37c3
#
#                       timestamp
# 0      2020-04-20T18:27:20.125Z  \
# 1      2020-04-20T18:27:23.764Z
# 2      2020-04-20T18:27:27.724Z
# 3      2020-04-20T18:27:30.410Z
# 4      2020-04-20T18:27:35.506Z
# ...                         ...
# 14883  2020-07-28T22:36:22.226Z
# 14884  2020-07-28T22:36:46.155Z
# ...

# %%
turns_df = preprocess_naive_turns(df)
turns_df.loc[turns_df['conversation_num'] == 0]
# Out:
#     batch_num  round_num          speaker_nickname                 timestamp
# 0           0          0  5e7e1e0031f4e454e196c30b  2020-04-20T18:27:20.125Z  \
# 1           0          0  5e31d6e4e31c5304c46f1413  2020-04-20T18:27:23.764Z
# 2           0          0  5e7e4f4c31f4e454e196c9c4  2020-04-20T18:27:27.724Z
# 3           0          0  5d482ea421c9be351f762255  2020-04-20T18:27:30.410Z
# 4           0          0  5e84cc3c50f6e364321d6265  2020-04-20T18:27:35.506Z
# 5           0          0  5d482ea621c9be351f762ae5  2020-04-20T18:28:09.451Z
# 6           0          0  5e84cc3c50f6e364321d6265  2020-04-20T18:28:20.136Z
# 7           0          0  5e7e4f4c31f4e454e196c9c4  2020-04-20T18:28:28.501Z
# 8           0          0  5e7e1e0031f4e454e196c30b  2020-04-20T18:28:30.530Z
# 9           0          0  5d482ea421c9be351f762255  2020-04-20T18:28:30.637Z
# 10          0          0  5e7e1e0031f4e454e196c30b  2020-04-20T18:28:50.848Z
# ...

# %%
turns_df
# Out:
#        batch_num  round_num          speaker_nickname
# 0              0          0  5e7e1e0031f4e454e196c30b  \
# 1              0          0  5e31d6e4e31c5304c46f1413
# 2              0          0  5e7e4f4c31f4e454e196c9c4
# 3              0          0  5d482ea421c9be351f762255
# 4              0          0  5e84cc3c50f6e364321d6265
# ...          ...        ...                       ...
# 13893        177          3  5f1f466846a7f03dda9b37c3
# 13894        177          3  5f1a214246a7f03dda9a6aad
# 13895        177          3  5f2096dab0aafc741f6865bb
# 13896        177          3  5f1f472646a7f03dda9b3895
# 13897        177          3  5f1f466846a7f03dda9b37c3
#
#                       timestamp
# 0      2020-04-20T18:27:20.125Z  \
# 1      2020-04-20T18:27:23.764Z
# 2      2020-04-20T18:27:27.724Z
# 3      2020-04-20T18:27:30.410Z
# 4      2020-04-20T18:27:35.506Z
# ...                         ...
# 13893  2020-07-28T22:36:22.226Z
# 13894  2020-07-28T22:36:46.155Z
# ...
