# %%
import pandas as pd

test_input_df = pd.read_csv("../test_turn_taking.csv")
test_conv_df_output =  pd.read_csv("../output/conv/test_turn_taking_conversation_level.csv")
# # join test_input_df with test_conv_df_output on conversation_num id
test_conv_df = pd.merge(test_conv_df_output, test_input_df, on='conversation_num')
test_conv_df_output.head(5)
# Out:
#    conversation_num  gini_coefficient_sum_num_words  \
# 0                 1                        0.166667
# 1                 2                        0.000000
# 2                 3                        0.100000
# 3                 4                        0.222772
# 4                 5                        0.166667
#
#    gini_coefficient_sum_num_chars  gini_coefficient_sum_num_messages  \
# 0                        0.055556                           0.100000
# 1                        0.000000                           0.000000
# 2                        0.107143                           0.100000
# 3                        0.218884                           0.318182
# 4                        0.184211                           0.166667
#
#    average_positive_bert  stdev_positive_bert  min_positive_bert  \
# 0               0.325452             0.075737           0.230796
# 1               0.116947             0.044204           0.072743
# ...
