# %%
# import basic_features 
import pandas as pd
import sys 
import os

# %%
sys.path.append('/Users/xehu/Desktop/Team Process Map/team-process-map/feature_engine/')

# %%
print(sys.path)
# Out:
# ['/Users/xehu/Desktop/Team Process Map/team-process-map/feature_engine/ipython_notebooks', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python39.zip', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload', '', '/Users/xehu/Library/Python/3.9/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/smile_and_nod-0.0.1-py3.9.egg', '/Users/xehu/Library/Python/3.9/lib/python/site-packages/IPython/extensions', '/Users/xehu/.ipython', '/Users/xehu/Desktop/Team Process Map/team-process-map/feature_engine/']

# %%
from features.basic_features import *
from features.gini_coefficient import *

# %%
print(sys.path)
# Out:
# ['/Users/xehu/Desktop/Team Process Map/team-process-map/feature_engine/ipython_notebooks', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python39.zip', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload', '', '/Users/xehu/Library/Python/3.9/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/smile_and_nod-0.0.1-py3.9.egg', '/Users/xehu/Library/Python/3.9/lib/python/site-packages/IPython/extensions', '/Users/xehu/.ipython', '/Users/xehu/Desktop/Team Process Map/team-process-map/feature_engine/']

# %%
# test file
INPUT_FILE_PATH = '../output/jury_output_chat_level.csv'
conversation_data = pd.read_csv(INPUT_FILE_PATH)

conversation_data
# Out:
#        Unnamed: 0  batch_num  round_num              speaker_hash  \
# 0               0          0          0  5e7e1e0031f4e454e196c30b
# 1               1          0          0  5e31d6e4e31c5304c46f1413
# 2               2          0          0  5e7e4f4c31f4e454e196c9c4
# 3               3          0          0  5d482ea421c9be351f762255
# 4               4          0          0  5e84cc3c50f6e364321d6265
# ...           ...        ...        ...                       ...
# 15302       15302        177          3  5f1f466846a7f03dda9b37c3
# 15303       15303        177          3  5f1a214246a7f03dda9a6aad
# 15304       15304        177          3  5f2096dab0aafc741f6865bb
# 15305       15305        177          3  5f1f472646a7f03dda9b3895
# 15306       15306        177          3  5f1f466846a7f03dda9b37c3
#
#        speaker_nickname                 timestamp  \
# 0             niceRhino  2020-04-20T18:27:20.125Z
# 1           culturedCow  2020-04-20T18:27:23.764Z
# ...

# %%
get_message_counts(conversation_data).to_csv()
# Out:
#     batch_num  round_num speaker_nickname  num_messages
# 0           0          0     culturedBear             6
# 1           0          0      culturedCow             5
# 2           0          0   littleSquirrel             1
# 3           0          0        niceRhino             8
# 4           0          0     smallGiraffe             8
# ..        ...        ...              ...           ...
# 95          7          1     likelyRabbit             8
# 96          7          1      littleHippo             8
# 97          7          1        niceRhino            10
# 98          7          1    snappyGiraffe             8
# 99          7          1         spryLion             8
#
# [100 rows x 4 columns]

# %%
least_talkative_member_message_count(conversation_data)
# Out:
#       batch_num  round_num  least_talkative_member_message_count
# 0             0          0                                     1
# 1             0          0                                     1
# 2             0          0                                     1
# 3             0          0                                     1
# 4             0          0                                     1
# ...         ...        ...                                   ...
# 2365        177          3                                     6
# 2366        177          3                                     6
# 2367        177          3                                     6
# 2368        177          3                                     6
# 2369        177          3                                     6
#
# [2370 rows x 3 columns]

# %%
average_word_count(conversation_data)
# Out:
#       batch_num  round_num  average_word_count
# 0             0          0             107.125
# 1             0          0             107.125
# 2             0          0             107.125
# 3             0          0             107.125
# 4             0          0             107.125
# ...         ...        ...                 ...
# 2365        177          3             107.000
# 2366        177          3             107.000
# 2367        177          3             107.000
# 2368        177          3             107.000
# 2369        177          3             107.000
#
# [2370 rows x 3 columns]

# %%
get_gini(conversation_data, "num_words")
# Out:
#      batch_num  round_num  gini_coefficient_num_words
# 0            0          0                    0.158256
# 1            0          2                    0.125695
# 2            1          0                    0.220530
# 3            1          3                    0.261432
# 4            2          2                    0.112651
# ..         ...        ...                         ...
# 351        175          3                    0.317460
# 352        176          0                    0.363415
# 353        176          3                    0.326087
# 354        177          2                    0.146035
# 355        177          3                    0.223261
#
# [356 rows x 3 columns]
