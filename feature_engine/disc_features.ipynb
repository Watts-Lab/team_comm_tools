# %%
import pandas as pd
import numpy as np

# %%
def preprocess_conversation_columns(df):
	# remove all special characters from df
	df.columns = df.columns.str.replace('[^A-Za-z0-9_]', '', regex=True)
	
	# If data is grouped by batch/round, add a conversation num
	if {'batch_num', 'round_num'}.issubset(df.columns):
		df['conversation_num'] = df.groupby(['batch_num', 'round_num']).ngroup()
		df = df[df.columns.tolist()[-1:] + df.columns.tolist()[0:-1]] # make the new column first

	return(df)

# %%
test_dd = preprocess_conversation_columns(pd.read_csv('./data/raw_data/test_dd.csv'))
test_dd_vect = pd.read_csv('./embeddings/test_dd.csv')

# %%
csop = preprocess_conversation_columns(pd.read_csv('./data/raw_data/csopII_conversations_withblanks.csv'))
vect = pd.read_csv('./embeddings/csopII_conversations_withblanks.csv')

# %%
from features.get_all_DD_features import *

# %%
test_dd['message_embedding'] = conv_to_float_arr(test_dd_vect['message_embedding'].to_frame())
csop['message_embedding'] = conv_to_float_arr(vect['message_embedding'].to_frame())

# %%
# look at a unit case just for testing
csop = csop[csop["conversation_num"].isin(["25PJSrbtr8mkHTvcw_easy","cb2KMXFqSt2fJqRoa_hard"])]

# %%
get_DD(test_dd)
# Out:
#    conversation_num  discursive_diversity
# 0                 1          3.870704e-01
# 1                 2          8.280833e-01
# 2                 3         -2.220446e-16

# %%
get_DD(csop)
# Out:
#          conversation_num  discursive_diversity
# 0  25PJSrbtr8mkHTvcw_easy              0.726263
# 1  cb2KMXFqSt2fJqRoa_hard              0.630427

# %%
nanp = csop.loc[csop['conversation_num'] == '28LFTFoBTha9WeCxT_easy']
hi = np.mean(nanp['message_embedding'])
pairs = get_unique_pairwise_combos(hi)
np.nanmean(pairs)
# Out:
# 0.0013878469461957733

# %%
csop.loc[csop['conversation_num'] == '25PJSrbtr8mkHTvcw_easy']
# Out:
#            conversation_num  batch_num vis_img int_verb ort_img rep_man
# 727  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High  \
# 728  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
# 729  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
# 730  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
#
#     soc_pers  team_size                            difficulty  score
# 727    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0  \
# 728    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0
# 729    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0
# 730    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0
#
#      duration  efficiency   speaker_nickname
# 727     559.0    1.080501  NiBqtamR7LYPByEoz  \
# 728     559.0    1.080501  NiBqtamR7LYPByEoz
# 729     559.0    1.080501  NiBqtamR7LYPByEoz
# 730     559.0    1.080501  hF7iWkQvsomPnXY7S
#
#                                                message
# 727  I think the next combination above 500 that wo...  \
# 728                     I think 504 would still be ok?
# 729                                            604-100
# 730                                               sure
#
#                     timestamp
# 727  2021-03-19T18:20:28.277Z  \
# 728  2021-03-19T18:22:33.265Z
# 729  2021-03-19T18:22:41.278Z
# 730  2021-03-19T18:22:50.937Z
#
#                                      message_embedding
# 727  [0.019077956676483154, -0.010986157692968845, ...
# 728  [-0.025425974279642105, 0.08265340328216553, -...
# 729  [-0.03982073813676834, 0.08185562491416931, -0...
# 730  [-0.13950251042842865, -0.03979048505425453, -...

# %%
test_dd_chunked = assign_chunk_nums(test_dd, 3)
test_dd_chunked
# Out:
#     conversation_num speaker_nickname                 timestamp
# 0                  1                A  2020-04-20T18:27:20.125Z  \
# 1                  1                B  2020-04-20T18:27:23.764Z
# 2                  1                C  2020-04-20T18:27:27.724Z
# 3                  1                A  2020-04-20T18:27:30.410Z
# 4                  1                B  2020-04-20T18:27:35.506Z
# 5                  1                C  2020-04-20T18:28:09.451Z
# 6                  1                A  2020-04-20T18:28:20.136Z
# 7                  1                B  2020-04-20T18:28:20.136Z
# 8                  2                A  2020-04-20T18:27:20.125Z
# 9                  2                B  2020-04-20T18:27:23.764Z
# 10                 2                C  2020-04-20T18:27:27.724Z
# 11                 2                A  2020-04-20T18:27:30.410Z
# 12                 2                B  2020-04-20T18:27:35.506Z
# 13                 2                C  2020-04-20T18:28:09.451Z
# 14                 2                A  2020-04-20T18:28:20.136Z
# 15                 2                B  2020-04-20T18:28:20.136Z
# 16                 3                A  2020-04-20T18:27:20.125Z
# 17                 3                B  2020-04-20T18:27:23.764Z
# 18                 3                C  2020-04-20T18:27:27.724Z
# 19                 3                A  2020-04-20T18:27:30.410Z
# 20                 3                B  2020-04-20T18:27:35.506Z
# 21                 3                C  2020-04-20T18:28:09.451Z
# 22                 3                A  2020-04-20T18:28:20.136Z
# 23                 3                B  2020-04-20T18:28:20.136Z
#
#                                               message  majority_pct
# 0                  Hey, folks! What a sunny day, huh?             1  \
# 1   Totally! The weather's awesome. Perfect for a ...             1
# 2   Absolutely! The sun's warmth lifts my spirits....             1
# 3   Your enthusiasm is contagious. We're like a sy...             1
# 4   Exactly! Our thoughts harmonize effortlessly, ...             1
# 5   Well said! Our words sway together, a testamen...             1
# 6   Your eloquence is inspiring! We're instruments...             1
# 7   Beautifully put! Our conversation is a masterp...             1
# 8   Salutations, esteemed companions! Have you eve...             1
# 9   Yo, folks! Guess what? Last night's game was i...             1
# 10  Hey, everyone! Let's embark on a culinary adve...             1
# 11  The wonders of quantum mechanics never cease t...             1
# 12  Dude, that game was off the charts! The team p...             1
# 13  Ah, the world of gastronomy! A realm where cul...             1
# 14  Quantum mechanics unravels the mysteries of th...             1
# 15  Man, sports bring people together! The energy ...             1
# 16  Hello! This is a test sentence in which we all...             1
# 17  Hello! This is a test sentence in which we all...             1
# 18  Hello! This is a test sentence in which we all...             1
# 19  Hello! This is a test sentence in which we all...             1
# 20  Hello! This is a test sentence in which we all...             1
# 21  Hello! This is a test sentence in which we all...             1
# 22  Hello! This is a test sentence in which we all...             1
# 23  Hello! This is a test sentence in which we all...             1
#
#     num_flipped  flipped_pct  num_votes
# 0             1     0.333333          3  \
# 1             1     0.333333          3
# 2             1     0.333333          3
# 3             1     0.333333          3
# 4             1     0.333333          3
# 5             1     0.333333          3
# 6             1     0.333333          3
# 7             1     0.333333          3
# 8             1     0.333333          3
# 9             1     0.333333          3
# 10            1     0.333333          3
# 11            1     0.333333          3
# 12            1     0.333333          3
# 13            1     0.333333          3
# 14            1     0.333333          3
# 15            1     0.333333          3
# 16            1     0.333333          3
# 17            1     0.333333          3
# 18            1     0.333333          3
# 19            1     0.333333          3
# 20            1     0.333333          3
# 21            1     0.333333          3
# 22            1     0.333333          3
# 23            1     0.333333          3
#
#                                     message_embedding chunk_num
# 0   [-0.05474695563316345, 0.03426985442638397, 0....         0
# 1   [-0.07623177021741867, -0.03382902592420578, 0...         0
# 2   [0.022043755277991295, 0.06103178858757019, 0....         0
# 3   [-0.00782862026244402, -0.12148767709732056, 0...         1
# 4   [0.026491936296224594, -0.0734446570277214, 0....         1
# 5   [0.02942504733800888, 0.006728546228259802, 0....         1
# 6   [-0.0029373159632086754, -0.038919854909181595...         2
# 7   [-0.039978738874197006, 0.02529899962246418, 0...         2
# 8   [-0.04252244532108307, -0.045107126235961914, ...         0
# 9   [0.013962630182504654, 0.024840209633111954, 0...         0
# 10  [-0.024859678000211716, -0.09123209118843079, ...         0
# 11  [-0.051735371351242065, -0.08504731953144073, ...         1
# 12  [0.02194618619978428, 0.09317155927419662, 0.0...         1
# 13  [0.008950394578278065, -0.016166768968105316, ...         1
# 14  [-0.08999428898096085, 0.02500457689166069, -0...         2
# 15  [0.051622290164232254, 0.06192368268966675, 0....         2
# 16  [0.028341859579086304, 0.06234437972307205, 0....         0
# 17  [0.028341859579086304, 0.06234437972307205, 0....         0
# 18  [0.028341859579086304, 0.06234437972307205, 0....         0
# 19  [0.028341859579086304, 0.06234437972307205, 0....         1
# 20  [0.028341859579086304, 0.06234437972307205, 0....         1
# 21  [0.028341859579086304, 0.06234437972307205, 0....         1
# 22  [0.028341859579086304, 0.06234437972307205, 0....         2
# 23  [0.028341859579086304, 0.06234437972307205, 0....         2

# %%
csop_chunked = assign_chunk_nums(csop, 3)
csop_chunked
# Out:
#             conversation_num  batch_num vis_img int_verb ort_img rep_man
# 727   25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High  \
# 728   25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
# 729   25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
# 730   25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
# 2527  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2528  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2529  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2530  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2531  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2532  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2533  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2534  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2535  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2536  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2537  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2538  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2539  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
# 2540  cb2KMXFqSt2fJqRoa_hard          1     Low      Low     Low     Low
#
#      soc_pers  team_size                                  difficulty  score
# 727     Mixed          2        Easy [Corresponds to 'Hard' in PNAS]  604.0  \
# 728     Mixed          2        Easy [Corresponds to 'Hard' in PNAS]  604.0
# 729     Mixed          2        Easy [Corresponds to 'Hard' in PNAS]  604.0
# 730     Mixed          2        Easy [Corresponds to 'Hard' in PNAS]  604.0
# 2527     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2528     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2529     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2530     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2531     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2532     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2533     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2534     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2535     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2536     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2537     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2538     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2539     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
# 2540     High          7  Hard [Corresponds to 'Super Hard' in PNAS]  916.0
#
#       duration  efficiency   speaker_nickname
# 727      559.0    1.080501  NiBqtamR7LYPByEoz  \
# 728      559.0    1.080501  NiBqtamR7LYPByEoz
# 729      559.0    1.080501  NiBqtamR7LYPByEoz
# 730      559.0    1.080501  hF7iWkQvsomPnXY7S
# 2527     431.0    2.125290  TtbAvteZKizwoyHeQ
# 2528     431.0    2.125290  TtbAvteZKizwoyHeQ
# 2529     431.0    2.125290  WiuwFxezEg3uSYY5J
# 2530     431.0    2.125290  ajAi4jxzqEwxpTvC4
# 2531     431.0    2.125290  ajAi4jxzqEwxpTvC4
# 2532     431.0    2.125290  Q7Z4F3E6M2rPib8bp
# 2533     431.0    2.125290  WiuwFxezEg3uSYY5J
# 2534     431.0    2.125290  WiuwFxezEg3uSYY5J
# 2535     431.0    2.125290  ajAi4jxzqEwxpTvC4
# 2536     431.0    2.125290  TtbAvteZKizwoyHeQ
# 2537     431.0    2.125290  WiuwFxezEg3uSYY5J
# 2538     431.0    2.125290  WiuwFxezEg3uSYY5J
# 2539     431.0    2.125290  ajAi4jxzqEwxpTvC4
# 2540     431.0    2.125290  TtbAvteZKizwoyHeQ
#
#                                                 message
# 727   I think the next combination above 500 that wo...  \
# 728                      I think 504 would still be ok?
# 729                                             604-100
# 730                                                sure
# 2527                                                827
# 2528                                                894
# 2529                           Didn't we just have 899?
# 2530                     we did until someone moved one
# 2531               [ink you keep making our score worse
# 2532                                                916
# 2533                                   Well done, Pink.
# 2534         It's OK, Turqoise. We have time to adjust.
# 2535        I guess if you want to spend an hour for $6
# 2536                               how many more rounds
# 2537                                                 3?
# 2538                        Honestly, I already forgot.
# 2539    It can takeup to 60 minutes so I am assuming 10
# 2540  can all click satisfied so we can move to next...
#
#                      timestamp
# 727   2021-03-19T18:20:28.277Z  \
# 728   2021-03-19T18:22:33.265Z
# 729   2021-03-19T18:22:41.278Z
# 730   2021-03-19T18:22:50.937Z
# 2527  2021-03-10T18:25:03.752Z
# 2528  2021-03-10T18:25:10.189Z
# 2529  2021-03-10T18:25:18.538Z
# 2530  2021-03-10T18:25:31.682Z
# 2531  2021-03-10T18:26:52.241Z
# 2532  2021-03-10T18:26:55.465Z
# 2533  2021-03-10T18:26:58.017Z
# 2534  2021-03-10T18:27:21.649Z
# 2535  2021-03-10T18:27:39.192Z
# 2536  2021-03-10T18:28:33.903Z
# 2537  2021-03-10T18:28:42.673Z
# 2538  2021-03-10T18:29:03.537Z
# 2539  2021-03-10T18:29:08.513Z
# 2540  2021-03-10T18:29:23.850Z
#
#                                       message_embedding chunk_num
# 727   [0.019077956676483154, -0.010986157692968845, ...         0
# 728   [-0.025425974279642105, 0.08265340328216553, -...         0
# 729   [-0.03982073813676834, 0.08185562491416931, -0...         1
# 730   [-0.13950251042842865, -0.03979048505425453, -...         1
# 2527  [-0.05611119791865349, 0.055520616471767426, -...         0
# 2528  [0.0008462711703032255, 0.06286414712667465, -...         0
# 2529  [-0.058363933116197586, 0.0004796952707692981,...         0
# 2530  [0.052529413253068924, -0.050977353006601334, ...         0
# 2531  [-0.013198211789131165, 0.00264726928435266, 0...         0
# 2532  [-0.03465019911527634, 0.0510905496776104, -0....         1
# 2533  [-0.013680866919457912, 0.042766205966472626, ...         1
# 2534  [-0.009348239749670029, -0.043067533522844315,...         1
# 2535  [0.002892957767471671, -0.021120470017194748, ...         1
# 2536  [0.06289922446012497, 0.062271598726511, -0.05...         1
# 2537  [-0.034972529858350754, -0.09318390488624573, ...         2
# 2538  [-0.06569784134626389, -0.03449823334813118, 0...         2
# 2539  [0.0014496613293886185, -0.008836911991238594,...         2
# 2540  [0.0018908712081611156, -0.04364408180117607, ...         2

# %%
conv = csop_chunked.loc[csop_chunked['conversation_num'] == '25PJSrbtr8mkHTvcw_easy']

# %%
saving = conv.groupby(['chunk_num'])['message_embedding'].apply(get_unique_pairwise_combos).reset_index()
# lst = saving['message_embedding'][0]
cos_dists_mean_widay_btwu = []

for lst in saving.message_embedding:

    # Make sure list isn't empty:
    if lst:
        # Store the cosine distances for the person's list of tuples
        cos_dists = []
        for tpl in lst:
            try:
                cos_d = 1 - get_cosine_similarity([tpl[0], tpl[1]])
                cos_dists.append(cos_d)
            except ValueError as e:
                # Occurs when np.nan in tuple
                pass

        # Compute mean of cos dists
        cos_dists_mean_widay_btwu.append(np.nanmean(cos_dists, dtype="float64"))
    else:
        cos_dists_mean_widay_btwu.append(np.nan)
cos_dists_mean_widay_btwu
# Out:
# [0.5788580914150436, 0.6963058408938405]

# %%
csop_chunked.loc[(csop_chunked['conversation_num'] == '25PJSrbtr8mkHTvcw_easy') & (csop_chunked['chunk_num'] == '0')]
# Out:
#            conversation_num  batch_num vis_img int_verb ort_img rep_man
# 727  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High  \
# 728  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
#
#     soc_pers  team_size                            difficulty  score
# 727    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0  \
# 728    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0
#
#      duration  efficiency   speaker_nickname
# 727     559.0    1.080501  NiBqtamR7LYPByEoz  \
# 728     559.0    1.080501  NiBqtamR7LYPByEoz
#
#                                                message
# 727  I think the next combination above 500 that wo...  \
# 728                     I think 504 would still be ok?
#
#                     timestamp
# 727  2021-03-19T18:20:28.277Z  \
# 728  2021-03-19T18:22:33.265Z
#
#                                      message_embedding chunk_num
# 727  [0.019077956676483154, -0.010986157692968845, ...         0
# 728  [-0.025425974279642105, 0.08265340328216553, -...         0

# %%
csop_chunked.loc[(csop_chunked['conversation_num'] == '25PJSrbtr8mkHTvcw_easy') & (csop_chunked['chunk_num'] == '1')]
# Out:
#            conversation_num  batch_num vis_img int_verb ort_img rep_man
# 729  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High  \
# 730  25PJSrbtr8mkHTvcw_easy          1   Mixed     High     Low    High
#
#     soc_pers  team_size                            difficulty  score
# 729    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0  \
# 730    Mixed          2  Easy [Corresponds to 'Hard' in PNAS]  604.0
#
#      duration  efficiency   speaker_nickname  message
# 729     559.0    1.080501  NiBqtamR7LYPByEoz  604-100  \
# 730     559.0    1.080501  hF7iWkQvsomPnXY7S     sure
#
#                     timestamp
# 729  2021-03-19T18:22:41.278Z  \
# 730  2021-03-19T18:22:50.937Z
#
#                                      message_embedding chunk_num
# 729  [-0.03982073813676834, 0.08185562491416931, -0...         1
# 730  [-0.13950251042842865, -0.03979048505425453, -...         1

# %%
csop_chunked.loc[(csop_chunked['conversation_num'] == '25PJSrbtr8mkHTvcw_easy') & (csop_chunked['chunk_num'] == '2')]
# Out:
# Empty DataFrame
# Columns: [conversation_num, batch_num, vis_img, int_verb, ort_img, rep_man, soc_pers, team_size, difficulty, score, duration, efficiency, speaker_nickname, message, timestamp, message_embedding, chunk_num]
# Index: []

# %%
csop_chunked.groupby(['conversation_num', 'chunk_num']).apply(get_DD)
# Out:
#                                           conversation_num
# conversation_num       chunk_num
# 25PJSrbtr8mkHTvcw_easy 0         0  25PJSrbtr8mkHTvcw_easy  \
#                        1         0  25PJSrbtr8mkHTvcw_easy
#
#                                     discursive_diversity
# conversation_num       chunk_num
# 25PJSrbtr8mkHTvcw_easy 0         0                   NaN
#                        1         0              0.696306

# %%
print(csop_chunked.groupby(['conversation_num', 'chunk_num']).apply(get_DD).to_string())
# Out:
#                                           conversation_num  discursive_diversity
# conversation_num       chunk_num
# 25PJSrbtr8mkHTvcw_easy 0         0  25PJSrbtr8mkHTvcw_easy                   NaN
#                        1         0  25PJSrbtr8mkHTvcw_easy              0.696306

# %%
get_variance_in_DD(csop_chunked)
# Out:
#          conversation_num  variance_in_DD
# 0  25PJSrbtr8mkHTvcw_easy             NaN

# %%
# num_chunks = 3
# inter_chunk_range = [ [] for i in range(num_chunks - 1)]

# index = []
# for i in range(num_chunks - 1):
#     index.append("c" + str(i) + "_c" + str(i + 1))
# index
# pd.DataFrame(inter_chunk_range, index=index).T

get_within_person_disc_range(csop_chunked, num_chunks = 3)

### CURIOSITY - how did we get values for c1_c2 for `25PJSrbtr8mkHTvcw_easy`?
## There are only 2 chunks in this case...
# Out:
# [[0.6145188155861171, 0.8391692977533936, 0.7256118569586198, 0.8045276377162043, 0.9434096943299545, 0.9203022188120703], [0.8369321887883662, 0.8391692977533936, 0.7256118569586198, 0.6521813408319573, 0.7693649028182898, 0.7262687221547542]]
#                            c0_c1     c1_c2
# conversation_num
# 25PJSrbtr8mkHTvcw_easy  0.614519  0.836932
# 25PJSrbtr8mkHTvcw_easy  0.839169  0.839169
# cb2KMXFqSt2fJqRoa_hard  0.725612  0.725612
# cb2KMXFqSt2fJqRoa_hard  0.804528  0.652181
# cb2KMXFqSt2fJqRoa_hard  0.943410  0.769365
# cb2KMXFqSt2fJqRoa_hard  0.920302  0.726269
#                         incongruent_modulation  within_person_disc_range
# conversation_num
# 25PJSrbtr8mkHTvcw_easy                0.012618                  1.564895
# cb2KMXFqSt2fJqRoa_hard                0.009574                  1.566820

# %%
get_within_person_disc_range(test_dd_chunked, num_chunks = 3)
# Out:
# [[0.8037338721586933, 0.8545239477097426, 0.7905633801890399, 0.3973550430249977, 0.3870970209021124, 0.40296760824260613, -2.220446049250313e-16, -2.220446049250313e-16, -2.220446049250313e-16], [0.554592139634682, 0.5210188197799636, 0.951488253423191, 0.3167915107063928, 0.3579536427190626, 0.9616013000252147, -2.220446049250313e-16, -2.220446049250313e-16, 0.8783546762031388]]
#                          c0_c1         c1_c2
# conversation_num
# 1                 8.037339e-01  5.545921e-01
# 1                 8.545239e-01  5.210188e-01
# 1                 7.905634e-01  9.514883e-01
# 2                 3.973550e-01  3.167915e-01
# 2                 3.870970e-01  3.579536e-01
# 2                 4.029676e-01  9.616013e-01
# 3                -2.220446e-16 -2.220446e-16
# 3                -2.220446e-16 -2.220446e-16
# 3                -2.220446e-16  8.783547e-01
#                   incongruent_modulation  within_person_disc_range
# conversation_num
# 1                               0.038978                  1.491973
# 2                               0.086917                  0.941255
# 3                               0.171446                  0.292785
