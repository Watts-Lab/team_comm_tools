# %%
import pandas as pd
import numpy as np

# %%
def preprocess_conversation_columns(df):
	# remove all special characters from df
	df.columns = df.columns.str.replace('[^A-Za-z0-9_]', '', regex=True)
	
	# If data is grouped by batch/round, add a conversation num
	if {'batch_num', 'round_num'}.issubset(df.columns):
		df['conversation_num'] = df.groupby(['batch_num', 'round_num']).ngroup()
		df = df[df.columns.tolist()[-1:] + df.columns.tolist()[0:-1]] # make the new column first

	return(df)

# %%
csop = preprocess_conversation_columns(pd.read_csv('../data/raw_data/csopII_conversations_withblanks.csv'))
vect = pd.read_csv('../embeddings/csopII_conversations_withblanks.csv')

# %%
from get_all_DD_features import *

# %%
csop['message_embedding'] = conv_to_float_arr(vect['message_embedding'].to_frame())

# %%
get_DD(csop)
# nanp = csop.loc[csop['conversation_num'] == '28LFTFoBTha9WeCxT']
# hi = np.mean(nanp['message_embedding'])
# pairs = get_unique_pairwise_combos(hi)
# np.nanmean(pairs)
# Out:
#       conversation_num  discursive_diversity
# 0    25PJSrbtr8mkHTvcw              0.841638
# 1    28LFTFoBTha9WeCxT                   NaN
# 2    28coGosspMQZSSsKK                   NaN
# 3    2GyDrExReibZDZbHK                   NaN
# 4    2PHmsZkuyuXMZcv7s                   NaN
# ..                 ...                   ...
# 476  zRx7pqdbWDwduoYuM              0.746014
# 477  zXofkTp388eu67YxF              0.524080
# 478  zdBGjnPDQBJoyZqjh              0.801704
# 479  zoijP9Z4yNJ8sRgZq                   NaN
# 480  zwtfREfmLE7LzyW7n              0.749704
#
# [481 rows x 2 columns]

# %%
csop.loc[csop['conversation_num'] == '25PJSrbtr8mkHTvcw']
# Out:
#        conversation_num  batch_num vis_img int_verb ort_img rep_man soc_pers
# 727   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed  \
# 728   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# 729   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# 730   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# 3099  25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
#
#       team_size                                  difficulty  score  duration
# 727           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0  \
# 728           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
# 729           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
# 730           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
# 3099          2  Hard [Corresponds to 'Super Hard' in PNAS]  729.0     179.0
#
#       efficiency   speaker_nickname
# 727     1.080501  NiBqtamR7LYPByEoz  \
# 728     1.080501  NiBqtamR7LYPByEoz
# 729     1.080501  NiBqtamR7LYPByEoz
# 730     1.080501  hF7iWkQvsomPnXY7S
# 3099    4.072626       NULL_SPEAKER
#
#                                                 message
# 727   I think the next combination above 500 that wo...  \
# 728                      I think 504 would still be ok?
# 729                                             604-100
# 730                                                sure
# 3099                                                NaN
#
#                      timestamp
# 727   2021-03-19T18:20:28.277Z  \
# 728   2021-03-19T18:22:33.265Z
# 729   2021-03-19T18:22:41.278Z
# 730   2021-03-19T18:22:50.937Z
# 3099                 NULL_TIME
#
#                                       message_embedding
# 727   [0.0190779697149992, -0.010986153967678547, -0...
# 728   [-0.02542596124112606, 0.08265342563390732, -0...
# 729   [-0.03982061892747879, 0.08185563236474991, -0...
# 730   [-0.1395024061203003, -0.03979051858186722, -0...
# 3099  [-0.0642978772521019, -0.028240203857421875, 0...

# %%
csop_chunked = assign_chunk_nums(csop, 5)
csop_chunked
# Out:
#        conversation_num  batch_num vis_img int_verb ort_img rep_man soc_pers
# 727   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed  \
# 728   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# 729   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# 730   25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# 3099  25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
# ...                 ...        ...     ...      ...     ...     ...      ...
# 253   zwtfREfmLE7LzyW7n          1    High    Mixed   Mixed   Mixed     High
# 254   zwtfREfmLE7LzyW7n          1    High    Mixed   Mixed   Mixed     High
# 255   zwtfREfmLE7LzyW7n          1    High    Mixed   Mixed   Mixed     High
# 256   zwtfREfmLE7LzyW7n          1    High    Mixed   Mixed   Mixed     High
# 2666  zwtfREfmLE7LzyW7n          1    High    Mixed   Mixed   Mixed     High
#
#       team_size                                  difficulty  score  duration
# 727           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0  \
# 728           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
# 729           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
# 730           2        Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
# 3099          2  Hard [Corresponds to 'Super Hard' in PNAS]  729.0     179.0
# ...         ...                                         ...    ...       ...
# 253           4        Easy [Corresponds to 'Hard' in PNAS]  537.0     294.0
# 254           4        Easy [Corresponds to 'Hard' in PNAS]  537.0     294.0
# 255           4        Easy [Corresponds to 'Hard' in PNAS]  537.0     294.0
# 256           4        Easy [Corresponds to 'Hard' in PNAS]  537.0     294.0
# 2666          4  Hard [Corresponds to 'Super Hard' in PNAS]  812.0     132.0
#
#       efficiency   speaker_nickname
# 727     1.080501  NiBqtamR7LYPByEoz  \
# 728     1.080501  NiBqtamR7LYPByEoz
# 729     1.080501  NiBqtamR7LYPByEoz
# 730     1.080501  hF7iWkQvsomPnXY7S
# 3099    4.072626       NULL_SPEAKER
# ...          ...                ...
# 253     1.826531  ttp99Mg4k27H4G4g2
# 254     1.826531  eiZmgSepzvcWzXZnq
# 255     1.826531  eiZmgSepzvcWzXZnq
# 256     1.826531  ReHqydvhHuWfF9wbc
# 2666    6.151515       NULL_SPEAKER
#
#                                                 message
# 727   I think the next combination above 500 that wo...  \
# 728                      I think 504 would still be ok?
# 729                                             604-100
# 730                                                sure
# 3099                                                NaN
# ...                                                 ...
# 253                              you have ruined it all
# 254                                  IT WAS FINE BEFORE
# 255                             AB HAVE TO BE NEIGHBORS
# 256                           can we please put it back
# 2666                                                NaN
#
#                      timestamp
# 727   2021-03-19T18:20:28.277Z  \
# 728   2021-03-19T18:22:33.265Z
# 729   2021-03-19T18:22:41.278Z
# 730   2021-03-19T18:22:50.937Z
# 3099                 NULL_TIME
# ...                        ...
# 253   2021-03-11T18:33:02.259Z
# 254   2021-03-11T18:33:11.705Z
# 255   2021-03-11T18:33:26.463Z
# 256   2021-03-11T18:33:29.370Z
# 2666                 NULL_TIME
#
#                                       message_embedding chunk_num
# 727   [0.0190779697149992, -0.010986153967678547, -0...         0
# 728   [-0.02542596124112606, 0.08265342563390732, -0...         1
# 729   [-0.03982061892747879, 0.08185563236474991, -0...         2
# 730   [-0.1395024061203003, -0.03979051858186722, -0...         3
# 3099  [-0.0642978772521019, -0.028240203857421875, 0...         4
# ...                                                 ...       ...
# 253   [-0.014426716603338718, 0.14449119567871094, 0...         2
# 254   [-0.026309503242373466, -0.029762502759695053,...         2
# 255   [0.022271981462836266, -0.0574793741106987, -0...         3
# 256   [-0.053512245416641235, 0.0669332817196846, 0....         3
# 2666  [-0.0642978772521019, -0.028240203857421875, 0...         4
#
# [4619 rows x 17 columns]

# %%
conv = csop_chunked.loc[csop_chunked['conversation_num'] == '25PJSrbtr8mkHTvcw']

# %%
saving = conv.groupby(['chunk_num'])['message_embedding'].apply(get_unique_pairwise_combos).reset_index()
# lst = saving['message_embedding'][0]
cos_dists_mean_widay_btwu = []

for lst in saving.message_embedding:

    # Make sure list isn't empty:
    if lst:
        # Store the cosine distances for the person's list of tuples
        cos_dists = []
        for tpl in lst:
            try:
                cos_d = 1 - get_cosine_similarity([tpl[0], tpl[1]])
                cos_dists.append(cos_d)
            except ValueError as e:
                # Occurs when np.nan in tuple
                pass

        # Compute mean of cos dists
        cos_dists_mean_widay_btwu.append(np.nanmean(cos_dists, dtype="float64"))
    else:
        cos_dists_mean_widay_btwu.append(np.nan)
cos_dists_mean_widay_btwu
# Out:
# [0.5788579683150291, 0.6963057582555213, nan]

# %%
conv = csop_chunked.loc[(csop_chunked['conversation_num'] == '25PJSrbtr8mkHTvcw') & (csop_chunked['chunk_num'] == '0')]
conv
# Out:
#       conversation_num  batch_num vis_img int_verb ort_img rep_man soc_pers
# 727  25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed  \
# 728  25PJSrbtr8mkHTvcw          1   Mixed     High     Low    High    Mixed
#
#      team_size                            difficulty  score  duration
# 727          2  Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0  \
# 728          2  Easy [Corresponds to 'Hard' in PNAS]  604.0     559.0
#
#      efficiency   speaker_nickname
# 727    1.080501  NiBqtamR7LYPByEoz  \
# 728    1.080501  NiBqtamR7LYPByEoz
#
#                                                message
# 727  I think the next combination above 500 that wo...  \
# 728                     I think 504 would still be ok?
#
#                     timestamp
# 727  2021-03-19T18:20:28.277Z  \
# 728  2021-03-19T18:22:33.265Z
#
#                                      message_embedding chunk_num
# 727  [0.0190779697149992, -0.010986153967678547, -0...         0
# 728  [-0.02542596124112606, 0.08265342563390732, -0...         0

# %%
csop_chunked.groupby(['conversation_num', 'chunk_num']).apply(get_DD)
# Out:
#                                 conversation_num  discursive_diversity
# conversation_num  chunk_num
# 25PJSrbtr8mkHTvcw 0         0  25PJSrbtr8mkHTvcw                   NaN
#                   1         0  25PJSrbtr8mkHTvcw              0.696306
#                   2         0  25PJSrbtr8mkHTvcw                   NaN
# 28LFTFoBTha9WeCxT 0         0  28LFTFoBTha9WeCxT                   NaN
#                   1         0  28LFTFoBTha9WeCxT                   NaN
# ...                                          ...                   ...
# zoijP9Z4yNJ8sRgZq 0         0  zoijP9Z4yNJ8sRgZq                   NaN
#                   1         0  zoijP9Z4yNJ8sRgZq                   NaN
# zwtfREfmLE7LzyW7n 0         0  zwtfREfmLE7LzyW7n              0.704767
#                   1         0  zwtfREfmLE7LzyW7n              0.496674
#                   2         0  zwtfREfmLE7LzyW7n              0.916253
#
# [1194 rows x 2 columns]

# %%
get_variance_in_DD(csop_chunked)
# Out:
#       conversation_num  variance_in_DD
# 0    25PJSrbtr8mkHTvcw        0.696306
# 1    28LFTFoBTha9WeCxT             NaN
# 2    28coGosspMQZSSsKK             NaN
# 3    2GyDrExReibZDZbHK             NaN
# 4    2PHmsZkuyuXMZcv7s             NaN
# ..                 ...             ...
# 476  zRx7pqdbWDwduoYuM        0.782127
# 477  zXofkTp388eu67YxF        0.644710
# 478  zdBGjnPDQBJoyZqjh        0.835775
# 479  zoijP9Z4yNJ8sRgZq             NaN
# 480  zwtfREfmLE7LzyW7n        0.705898
#
# [481 rows x 2 columns]

# %%
# num_chunks = 3
# inter_chunk_range = [ [] for i in range(num_chunks - 1)]

# index = []
# for i in range(num_chunks - 1):
#     index.append("c" + str(i) + "_c" + str(i + 1))
# index
# pd.DataFrame(inter_chunk_range, index=index).T

get_within_person_disc_range(csop_chunked)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /usr/local/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean_chunk_vec_c3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 10
#       1 # num_chunks = 3
#       2 # inter_chunk_range = [ [] for i in range(num_chunks - 1)]
#       3
#    (...)
#       7 # index
#       8 # pd.DataFrame(inter_chunk_range, index=index).T
# ---> 10 get_within_person_disc_range(csop_chunked)
#
# File ~/Documents/tpm/team-process-map/feature_engine/features/within_person_discursive_range.py:19, in get_within_person_disc_range(chat_data)
#      17 for index in range(num_chunks - 1):
#      18     tpl = [row['mean_chunk_vec_c' + str(index)], row['mean_chunk_vec_c'+ str(index+1)]]
# ---> 19     value = 0
#      20     if (pd.isnull(tpl)).any():
#      21         value = np.nan
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'mean_chunk_vec_c3'
